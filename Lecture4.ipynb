# %%
import pandas as pd
import numpy as np

# %%
#Missing something here

# %%
ser=pd.Series([1,3,4,1],index=['a','b','c','d'])#columns are not available in pd.Series

# %%
ser
# Out:
# a    1
# b    3
# c    4
# d    1
# dtype: int64

# %%
ata = pd.DataFrame(np.arange(16).reshape((4, 4)),index=['Ohio', 'Colorado', 'Utah', 'New York'], columns=['one', 'two', 'three', 'four'])

# %%
ata
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %% [markdown]
# # Index Object

# %%
o=pd.Series([2,42,2],index=['e','r','q'])
o
# Out:
# e     2
# r    42
# q     2
# dtype: int64

# %%
obj = pd.Series(range(3), index=['a', 'b', 'c'])
obj
# Out:
# a    0
# b    1
# c    2
# dtype: int64

# %%
index = obj.index
index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
index[1:]
# Out:
# Index(['b', 'c'], dtype='object')

# %% [markdown]
# # 5.2 Essential Functionality (Series)

# %%
obj2=obj.reindex(['a','c','b','d'])
obj2
# Out:
# a    0.0
# c    2.0
# b    1.0
# d    NaN
# dtype: float64

# %%
obj3 = pd.Series(['blue', 'purple', 'yellow'], index=[ 1,2, 4])

# %%
obj3
# Out:
# 1      blue
# 2    purple
# 4    yellow
# dtype: object

# %%
obj3.reindex(range(6), method='ffill')
# Out:
# 0       NaN
# 1      blue
# 2    purple
# 3    purple
# 4    yellow
# 5    yellow
# dtype: object

# %%
k=obj3.reindex(range(6), method='bfill')
k
# Out:
# 0      blue
# 1      blue
# 2    purple
# 3    yellow
# 4    yellow
# 5       NaN
# dtype: object

# %%
k.bfill()
# Out:
# 0      blue
# 1      blue
# 2    purple
# 3    yellow
# 4    yellow
# 5       NaN
# dtype: object

# %% [markdown]
# # Essential Functionality(Frame)

# %%
data = {'states': ['Ohio', 'Oio', 'Ohi', 'Neada', 'Nevad', 'evada'],'year': [2000, 2001, 2002, 2001, 2002, 2003],'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
q=pd.DataFrame(data,columns=['year','pop','def','states'],index=['one','two','three','four','five','six'])
q['def']=[1,3,3,1,3,1]

# %%
q
# Out:
#        year  pop  def states
# one    2000  1.5    1   Ohio
# two    2001  1.7    3    Oio
# three  2002  3.6    3    Ohi
# four   2001  2.4    1  Neada
# five   2002  2.9    3  Nevad
# six    2003  3.2    1  evada

# %%
pop = {'Nevada': {2001: 2.4, 2002: 2.9},'Ohio': {2000: 1.5, 2001: 1.7, 2002: 3.6}}
qq=pd.DataFrame(pop)
qq
# Out:
#       Nevada  Ohio
# 2000     NaN   1.5
# 2001     2.4   1.7
# 2002     2.9   3.6

# %%
frame = pd.DataFrame(np.arange(12).reshape((3, 4)),index=['a', 'c', 'd'],columns=['Ohio', 'Texas', 'California','Kalachi'])
frame
# Out:
#    Ohio  Texas  California  Kalachi
# a     0      1           2        3
# c     4      5           6        7
# d     8      9          10       11

# %%
fm=pd.DataFrame(np.arange(9).reshape(3,3),columns=list('abc'))
fm1=pd.DataFrame(np.arange(4).reshape(2,2),columns=list('ab'))

# %%
f=lambda x:x.max()-x.min()
frame.apply(f,axis=1)
# Out:
# a    2
# c    2
# d    2
# dtype: int64

# %%
fm1
# Out:
#    a  b
# 0  0  1
# 1  2  3

# %%
#fm.add(fm1,fill_value=0)
fm.add(fm1)
# Out:
#      a    b   c
# 0  0.0  2.0 NaN
# 1  5.0  7.0 NaN
# 2  NaN  NaN NaN

# %%
# Out:
#      a    b   c
# 0  0.0  2.0 NaN
# 1  5.0  7.0 NaN
# 2  NaN  NaN NaN

# %%
frame2 = frame.reindex(['a', 'b', 'c', 'd'])
frame2
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# b   NaN    NaN         NaN
# c   3.0    4.0         5.0
# d   6.0    7.0         8.0

# %%
states = ['Texas', 'Utah', 'California']
frame.reindex(columns=states)
# Out:
#    Texas  Utah  California
# a      1   NaN           2
# c      4   NaN           5
# d      7   NaN           8

# %% [markdown]
# # Colmn and row indexing

# %%
Newframe=frame.reindex(index=['a','b','c','d'],columns=['Texas','Utah','California','Mexico'])
Newframe.index.name='Population'
Newframe.columns.name='City->'
Newframe
# Out:
# City->      Texas  Utah  California  Mexico
# Population
# a             1.0   NaN         2.0     NaN
# b             NaN   NaN         NaN     NaN
# c             4.0   NaN         5.0     NaN
# d             7.0   NaN         8.0     NaN

# %% [markdown]
# # Droping Enteries from an axis

# %%
obj = pd.Series(np.arange(5.), index=['a', 'b', 'c', 'd', 'e'])
obj.drop(['e'])
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# dtype: float64

# %%
obj.drop(['d'],inplace=True)

# %%
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# e    4.0
# dtype: float64

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4)),index=['Ohio', 'Colorado', 'Utah', 'New York'],columns=['one', 'two', 'three', 'four'])
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data.drop(['Utah','Ohio'])
# Out:
#           one  two  three  four
# Colorado    4    5      6     7
# New York   12   13     14    15

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data.drop(['one'],axis=1)
# Out:
#           two  three  four
# Ohio        1      2     3
# Colorado    5      6     7
# Utah        9     10    11
# New York   13     14    15

# %%
data.drop(['two'])#we have to explicity write the axis to delete a column
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-89e41cba74a7> in <module>
# ----> 1 data.drop(['two'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# -> 3780                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3781
# ...

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %% [markdown]
# #Reading Data

# %%
df=pd.read_csv('student.csv')
df
# Out:
#     Student Code  Degree      Student Name  Mid  Quiz 1  Quiz 2  \
# 0   022-14-19987  BS(CS)       Abdul Basit   28     8.0       3
# 1  022-14-110233  BS(CS)       Adeel Ahmed   17     NaN       5
# 2  022-14-110585  BS(CS)      Afrah Zareen   18     5.0       2
# 3   022-14-19718  BS(CS)    Ahmed Ali Raza   14     7.0       2
# 4  022-14-110648  BS(CS)   Ahsan Ali Vohra   27     7.0       6
# 5  022-14-110232  BS(CS)       Ameer Hamza   25     9.0       6
# 6  022-14-110588  BS(CS)     Anas Ali Khan   28     5.0       6
# 7  022-14-110388  BS(CS)  Aneebullah Niazi   26     9.0       6
# 8  022-14-110601  BS(CS)    Areesha Sohail   19     9.0       4
# 9  022-14-110599  BS(CS)           Arsalan   28     8.0       6
#
#    Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                8           7.0           9.0                    9
# 1                5           8.0          10.0                   10
# ...

# %%
name=input('Enter Name ')
c=df.where(df['Student Name']==name)
c='pass' if nan in c else 'not' for nan in c
c
# Out:
#   File "<ipython-input-14-5e92b1721444>", line 3
#     c='pass' if nan in c else 'not' for nan in c
#                                       ^
# SyntaxError: invalid syntax

# %%
df.loc[9],['022-14-19987']
# Out:
# (Student Code            022-14-110599
#  Degree                         BS(CS)
#  Student Name                  Arsalan
#  Mid                                28
#  Quiz 1                              8
#  Quiz 2                              6
#  Best of Quizzes                     8
#  Assignment 1                        8
#  Assignment 2                      NaN
#  Best of Assignments                 8
#  Total Sessional (50)               44
#  Final (50)                         40
#  Total (100)                        84
#  Grade                               A
#  Name: 9, dtype: object, ['022-14-19987'])

# %%
df.head()
# Out:
#     Student Code  Degree     Student Name  Mid  Quiz 1  Quiz 2  \
# 0   022-14-19987  BS(CS)      Abdul Basit   28     8.0       3
# 1  022-14-110233  BS(CS)      Adeel Ahmed   17     NaN       5
# 2  022-14-110585  BS(CS)     Afrah Zareen   18     5.0       2
# 3   022-14-19718  BS(CS)   Ahmed Ali Raza   14     7.0       2
# 4  022-14-110648  BS(CS)  Ahsan Ali Vohra   27     7.0       6
#
#    Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                8           7.0           9.0                    9
# 1                5           8.0          10.0                   10
# 2                5           8.0          10.0                   10
# 3                7           NaN           2.0                    2
# 4                7           7.0           9.0                    9
#
#    Total Sessional (50)  Final (50)  Total (100) Grade
# 0                    45          25           70     B
# 1                    32          18           50     F
# ...

# %%
df.shape
# Out:
# (10, 14)

# %%
df.columns
# Out:
# Index(['Student Code', 'Degree', 'Student Name', 'Mid', 'Quiz 1', 'Quiz 2',
#        'Best of Quizzes', 'Assignment 1', 'Assignment 2',
#        'Best of Assignments', 'Total Sessional (50)', 'Final (50)',
#        'Total (100)', 'Grade'],
#       dtype='object')

# %%
df[df['Mid']>20]
# Out:
#     Student Code  Degree      Student Name  Mid  Quiz 1  Quiz 2  \
# 0   022-14-19987  BS(CS)       Abdul Basit   28     8.0       3
# 4  022-14-110648  BS(CS)   Ahsan Ali Vohra   27     7.0       6
# 5  022-14-110232  BS(CS)       Ameer Hamza   25     9.0       6
# 6  022-14-110588  BS(CS)     Anas Ali Khan   28     5.0       6
# 7  022-14-110388  BS(CS)  Aneebullah Niazi   26     9.0       6
# 9  022-14-110599  BS(CS)           Arsalan   28     8.0       6
#
#    Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                8           7.0           9.0                    9
# 4                7           7.0           9.0                    9
# 5                9           8.0          10.0                   10
# 6                6           8.0          10.0                   10
# 7                9           8.0          10.0                   10
# 9                8           8.0           NaN                    8
#
# ...

# %%
df[(df['Mid']>20)&(df['Best of Quizzes']>7)&(df['Best of Assignments']>5)&(df['Grade']=='A')]
# Out:
#     Student Code  Degree      Student Name  Mid  Quiz 1  Quiz 2  \
# 7  022-14-110388  BS(CS)  Aneebullah Niazi   26     9.0       6
# 9  022-14-110599  BS(CS)           Arsalan   28     8.0       6
#
#    Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 7                9           8.0          10.0                   10
# 9                8           8.0           NaN                    8
#
#    Total Sessional (50)  Final (50)  Total (100) Grade
# 7                    45          40           85     A
# 9                    44          40           84     A

# %%
dfc=df.copy()

# %%
dfc['Quiz 1'].fillna(dfc['Quiz 2'].mean())
dfc
# Out:
#     Student Code  Degree      Student Name  Mid  Quiz 1  Quiz 2  \
# 0   022-14-19987  BS(CS)       Abdul Basit   28     8.0       3
# 1  022-14-110233  BS(CS)       Adeel Ahmed   17     NaN       5
# 2  022-14-110585  BS(CS)      Afrah Zareen   18     5.0       2
# 3   022-14-19718  BS(CS)    Ahmed Ali Raza   14     7.0       2
# 4  022-14-110648  BS(CS)   Ahsan Ali Vohra   27     7.0       6
# 5  022-14-110232  BS(CS)       Ameer Hamza   25     9.0       6
# 6  022-14-110588  BS(CS)     Anas Ali Khan   28     5.0       6
# 7  022-14-110388  BS(CS)  Aneebullah Niazi   26     9.0       6
# 8  022-14-110601  BS(CS)    Areesha Sohail   19     9.0       4
# 9  022-14-110599  BS(CS)           Arsalan   28     8.0       6
#
#    Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                8           7.0           9.0                    9
# 1                5           8.0          10.0                   10
# ...

# %%
dfc.mean()
# Out:
# Mid                     23.000000
# Quiz 1                   7.444444
# Quiz 2                   4.600000
# Best of Quizzes          7.300000
# Assignment 1             7.666667
# Assignment 2             8.777778
# Best of Assignments      8.700000
# Total Sessional (50)    39.000000
# Final (50)              29.100000
# Total (100)             68.100000
# dtype: float64

# %%
dfc.fillna(0)
# Out:
#     Student Code  Degree      Student Name  Mid  Quiz 1  Quiz 2  \
# 0   022-14-19987  BS(CS)       Abdul Basit   28     8.0       3
# 1  022-14-110233  BS(CS)       Adeel Ahmed   17     0.0       5
# 2  022-14-110585  BS(CS)      Afrah Zareen   18     5.0       2
# 3   022-14-19718  BS(CS)    Ahmed Ali Raza   14     7.0       2
# 4  022-14-110648  BS(CS)   Ahsan Ali Vohra   27     7.0       6
# 5  022-14-110232  BS(CS)       Ameer Hamza   25     9.0       6
# 6  022-14-110588  BS(CS)     Anas Ali Khan   28     5.0       6
# 7  022-14-110388  BS(CS)  Aneebullah Niazi   26     9.0       6
# 8  022-14-110601  BS(CS)    Areesha Sohail   19     9.0       4
# 9  022-14-110599  BS(CS)           Arsalan   28     8.0       6
#
#    Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                8           7.0           9.0                    9
# 1                5           8.0          10.0                   10
# ...

# %%
dfc.fillna(dfc.mean())
# Out:
#     Student Code  Degree      Student Name  Mid    Quiz 1  Quiz 2  \
# 0   022-14-19987  BS(CS)       Abdul Basit   28  8.000000       3
# 1  022-14-110233  BS(CS)       Adeel Ahmed   17  7.444444       5
# 2  022-14-110585  BS(CS)      Afrah Zareen   18  5.000000       2
# 3   022-14-19718  BS(CS)    Ahmed Ali Raza   14  7.000000       2
# 4  022-14-110648  BS(CS)   Ahsan Ali Vohra   27  7.000000       6
# 5  022-14-110232  BS(CS)       Ameer Hamza   25  9.000000       6
# 6  022-14-110588  BS(CS)     Anas Ali Khan   28  5.000000       6
# 7  022-14-110388  BS(CS)  Aneebullah Niazi   26  9.000000       6
# 8  022-14-110601  BS(CS)    Areesha Sohail   19  9.000000       4
# 9  022-14-110599  BS(CS)           Arsalan   28  8.000000       6
#
#    Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                8      7.000000      9.000000                    9
# 1                5      8.000000     10.000000                   10
# ...

# %%
dfc['Student NameA']=np.where(dfc['Student Name'].index[0]=='A',True,False)
dfc['Status']=np.where(dfc['Grade']=='A',True,False)
dfc
# Out:
#     Student Code  Degree      Student Name  Mid  Quiz 1  Quiz 2  \
# 0   022-14-19987  BS(CS)       Abdul Basit   28     8.0       3
# 1  022-14-110233  BS(CS)       Adeel Ahmed   17     NaN       5
# 2  022-14-110585  BS(CS)      Afrah Zareen   18     5.0       2
# 3   022-14-19718  BS(CS)    Ahmed Ali Raza   14     7.0       2
# 4  022-14-110648  BS(CS)   Ahsan Ali Vohra   27     7.0       6
# 5  022-14-110232  BS(CS)       Ameer Hamza   25     9.0       6
# 6  022-14-110588  BS(CS)     Anas Ali Khan   28     5.0       6
# 7  022-14-110388  BS(CS)  Aneebullah Niazi   26     9.0       6
# 8  022-14-110601  BS(CS)    Areesha Sohail   19     9.0       4
# 9  022-14-110599  BS(CS)           Arsalan   28     8.0       6
#
#    Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                8           7.0           9.0                    9
# 1                5           8.0          10.0                   10
# ...

# %%
#del dfc['Student NameA']
dfc['Status']
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# 8    False
# 9     True
# Name: Status, dtype: bool

# %%
dfc[dfc['Student Name'].str.startswith('A')]
# Out:
#     Student Code  Degree      Student Name  Mid  Quiz 1  Quiz 2  \
# 0   022-14-19987  BS(CS)       Abdul Basit   28     8.0       3
# 1  022-14-110233  BS(CS)       Adeel Ahmed   17     NaN       5
# 2  022-14-110585  BS(CS)      Afrah Zareen   18     5.0       2
# 3   022-14-19718  BS(CS)    Ahmed Ali Raza   14     7.0       2
# 4  022-14-110648  BS(CS)   Ahsan Ali Vohra   27     7.0       6
# 5  022-14-110232  BS(CS)       Ameer Hamza   25     9.0       6
# 6  022-14-110588  BS(CS)     Anas Ali Khan   28     5.0       6
# 7  022-14-110388  BS(CS)  Aneebullah Niazi   26     9.0       6
# 8  022-14-110601  BS(CS)    Areesha Sohail   19     9.0       4
# 9  022-14-110599  BS(CS)           Arsalan   28     8.0       6
#
#    Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                8           7.0           9.0                    9
# 1                5           8.0          10.0                   10
# ...

# %%
c=pd.read_csv('student.csv')
c

# %%
c['Assignment 1'].fillna('empty')

# %%
c['Mid'].mean()
