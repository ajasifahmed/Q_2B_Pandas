# %%
import  lxml
import pandas as pd

# %%
tables = pd.read_html('fdic_failed_bank_list.html')

# %%
len(tables)
# Out:
# 1

# %%
tables = pd.read_html('https://www.fdic.gov/bank/individual/failed/banklist.html')
tables
# Out:
# [                                             Bank Name                City  \
#  0                                        Resolute Bank              Maumee
#  1                          Louisa Community Bank, Inc.              Louisa
#  2                                 The Enloe State Bank              Cooper
#  3                  Washington Federal Bank for Savings             Chicago
#  4      The Farmers and Merchants State Bank of Argonia             Argonia
#  5                                  Fayette County Bank          Saint Elmo
#  6    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
#  7                                       First NBC Bank         New Orleans
#  8                                        Proficio Bank  Cottonwood Heights
#  9                        Seaway Bank and Trust Company             Chicago
#  10                              Harvest Community Bank          Pennsville
# ...

# %%
ff=tables[0]
ff
# Out:
#                                              Bank Name                City  \
# 0                                        Resolute Bank              Maumee
# 1                          Louisa Community Bank, Inc.              Louisa
# 2                                 The Enloe State Bank              Cooper
# 3                  Washington Federal Bank for Savings             Chicago
# 4      The Farmers and Merchants State Bank of Argonia             Argonia
# 5                                  Fayette County Bank          Saint Elmo
# 6    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 7                                       First NBC Bank         New Orleans
# 8                                        Proficio Bank  Cottonwood Heights
# 9                        Seaway Bank and Trust Company             Chicago
# 10                              Harvest Community Bank          Pennsville
# ...

# %%
ff.head()
# Out:
#                                          Bank Name     City  ST   CERT  \
# 0                                    Resolute Bank   Maumee  OH  58317
# 1                      Louisa Community Bank, Inc.   Louisa  KY  58112
# 2                             The Enloe State Bank   Cooper  TX  10716
# 3              Washington Federal Bank for Savings  Chicago  IL  30570
# 4  The Farmers and Merchants State Bank of Argonia  Argonia  KS  17719
#
#                Acquiring Institution       Closing Date      Updated Date
# 0                 Buckeye State Bank   October 25, 2019  October 25, 2019
# 1  Kentucky Farmers Bank Corporation   October 25, 2019  October 25, 2019
# 2                 Legend Bank, N. A.       May 31, 2019   August 22, 2019
# 3                 Royal Savings Bank  December 15, 2017     July 24, 2019
# 4                        Conway Bank   October 13, 2017   August 12, 2019

# %%
close_timestamps = pd.to_datetime(ff['Closing Date'])
close_timestamps
# Out:
# 0     2019-10-25
# 1     2019-10-25
# 2     2019-05-31
# 3     2017-12-15
# 4     2017-10-13
# 5     2017-05-26
# 6     2017-05-05
# 7     2017-04-28
# 8     2017-03-03
# 9     2017-01-27
# 10    2017-01-13
# 11    2016-09-23
# 12    2016-08-19
# 13    2016-05-06
# 14    2016-04-29
# 15    2016-03-11
# 16    2015-10-02
# 17    2015-10-02
# 18    2015-07-10
# 19    2015-05-08
# 20    2015-02-27
# 21    2015-02-13
# 22    2015-01-23
# 23    2015-01-16
# 24    2014-12-19
# 25    2014-11-07
# 26    2014-10-24
# 27    2014-10-17
# 28    2014-07-25
# 29    2014-07-18
#          ...
# 528   2008-05-09
# 529   2008-03-07
# 530   2008-01-25
# 531   2007-10-04
# 532   2007-09-28
# 533   2007-02-02
# 534   2004-06-25
# 535   2004-03-19
# 536   2004-03-12
# 537   2004-02-14
# 538   2003-11-14
# 539   2003-05-09
# 540   2003-02-07
# 541   2002-12-17
# 542   2002-11-08
# 543   2002-09-30
# 544   2002-06-27
# 545   2002-06-26
# 546   2002-03-28
# 547   2002-03-01
# 548   2002-02-07
# ...

# %%
year=close_timestamps.dt.year.value_counts()
year
# Out:
# 2010    157
# 2009    140
# 2011     92
# 2012     51
# 2008     25
# 2013     24
# 2014     18
# 2002     11
# 2015      8
# 2017      8
# 2016      5
# 2001      4
# 2004      4
# 2019      3
# 2003      3
# 2007      3
# 2000      2
# Name: Closing Date, dtype: int64

# %%
close_timestamps.dt.day.value_counts()
# Out:
# 23    31
# 30    30
# 19    30
# 20    27
# 17    23
# 16    22
# 4     21
# 18    21
# 15    21
# 7     20
# 2     20
# 14    20
# 28    19
# 27    19
# 24    19
# 22    18
# 11    18
# 21    17
# 29    16
# 13    16
# 26    16
# 5     16
# 25    15
# 10    14
# 8     14
# 6     14
# 12    10
# 9     10
# 31     9
# 1      8
# 3      4
# Name: Closing Date, dtype: int64

# %%
close_timestamps.dt.month.value_counts()
# Out:
# 7     74
# 10    61
# 4     59
# 1     51
# 5     44
# 2     44
# 8     41
# 3     40
# 9     38
# 6     36
# 12    35
# 11    35
# Name: Closing Date, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr=np.array(year)
arr
# Out:
# array([157, 140,  92,  51,  25,  24,  18,  11,   8,   8,   5,   4,   4,
#          3,   3,   3,   2], dtype=int64)

# %%
plt.plot(arr)

# %% [markdown]
# # Parsing Xml with lxml.objectify
